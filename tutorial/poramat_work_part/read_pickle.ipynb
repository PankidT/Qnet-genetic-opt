# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
from all_function import *
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
visualize_result(path="results/for_test_plot_function", plot=True)
# Out:
# /Users/poramat/Documents/qwanta/tutorial/poramat_work_part/Genetic_algorithm_development/ga_Develop_I.py:253: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r.-" (-> color='r'). The keyword argument will take precedence.
#   ax[1, 1].plot(x, mean_cost, 'r.-', label='mean cost', color=color)
# /Users/poramat/Documents/qwanta/tutorial/poramat_work_part/Genetic_algorithm_development/ga_Develop_I.py:260: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b+" (-> color='b'). The keyword argument will take precedence.
#   ax[1, 1].plot(x, min_cost, 'b+',label='min cost', color=color)
