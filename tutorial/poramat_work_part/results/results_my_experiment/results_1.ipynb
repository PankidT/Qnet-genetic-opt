# %%
import sys
sys.path.insert(0, '/Users/poramat/Documents/qwanta/tutorial/poramat_work_part/Genetic_algorithm_development')
sys.path.insert(1, '/Users/poramat/Documents/qwanta/tutorial/poramat_work_part')

import pickle
import matplotlib.pyplot as plt
import numpy as np
from ga_Develop_I import *

# %%
with open("experiment_mutationSigma_1", "rb") as f:
    mutateSigma_1_object = pickle.load(f)
with open("experiment_mutationSigma_5", "rb") as f:
    mutateSigma_5_object = pickle.load(f)
with open("experiment_mutationSigma_9", "rb") as f:
    mutateSigma_9_object = pickle.load(f)

with open("experiment_weight_20_80", "rb") as f:
    weight_20_80_object = pickle.load(f)
with open("experiment_weight_50_50", "rb") as f:
    weight_50_50_object = pickle.load(f)
with open("experiment_weight_20_80", "rb") as f:
    weight_80_20_object = pickle.load(f)

# %%
mutateSigma_1_object.experiment_config['ga_object'].plot()

# %%
mutateSigma_5_object.experiment_config['ga_object'].plot()

# %%
mutateSigma_9_object.experiment_config['ga_object'].plot()

# %%
weight_20_80_object.experiment_config['ga_object'].plot()

# %%
weight_50_50_object.experiment_config['ga_object'].plot()

# %%
weight_80_20_object.experiment_config['ga_object'].plot()

# %%
with open("../for_test_plot_function", "rb") as f:
    test = pickle.load(f)

# %%
test.plot()
# Out:
# /Users/poramat/Documents/qwanta/tutorial/poramat_work_part/Genetic_algorithm_development/ga_Develop_I.py:255: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r.-" (-> color='r'). The keyword argument will take precedence.
#   ax[1, 1].plot(x, mean_cost, 'r.-', label='mean cost', color=color)
# /Users/poramat/Documents/qwanta/tutorial/poramat_work_part/Genetic_algorithm_development/ga_Develop_I.py:262: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b+" (-> color='b'). The keyword argument will take precedence.
#   ax[1, 1].plot(x, min_cost, 'b+',label='min cost', color=color)

# %%
test.table()
# Out:
# Best fidelity: 0.5558333333333334
#           loss (dB/km)  memory_time (second)  gate_error (%)  \
# Baseline       0.00552              0.561335        0.021766
# Solution       0.00552              0.561335        0.021766
#
#           measurement_error (%)
# Baseline               0.028797
# Solution               0.028797
